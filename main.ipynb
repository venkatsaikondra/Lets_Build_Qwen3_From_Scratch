# %%
import torch
from torch import nn
import torch.nn.functional as F
# Out:
# /Users/kpvarma/PycharmProjects/Lets_Build_Qwen3_From_Scratch/.venv/lib/python3.13/site-packages/torch/_subclasses/functional_tensor.py:362: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at /Users/runner/work/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))

# %%
class RMSNorm(nn.Module):
    def __init__(self, dim: int, eps: float = 1e-6):
        super().__init__()

        self.weight = nn.Parameter(torch.ones(dim))
        self.eps = eps

    def norm(self, x: torch.Tensor):
        rms = torch.sqrt(x.pow(2).mean(-1, keepdim=True) + self.eps)
        return x / rms

    def forward(self, x: torch.Tensor):
        out = self.norm(x)
        out = out * self.weight
        return out

class RoPE(nn.Module):
    def _init_(self,cofig):
        super()._init_()
class SelfAttention(nn.Module):
    def _init_(self,cofig):
        super()._init_()

class GatedDeltaNet(nn.Module):
    def _init_(self,cofig):
        super()._init_()

class Decoder(nn.Module):
    def _init_(self,cofig):
        super()._init_()

class DynamicCache(nn.Module):
    def _init_(self,cofig):
        super()._init_()

class TextModel(nn.Module):
    def _init_(self,cofig):
        super()._init_()

if __name__ == "__main__":
    norm = RMSNorm(64)
    out = norm(torch.randn(4, 20, 64))
    #print(out.shape)
    print(out)
# Out:
# tensor([[[-1.1405,  0.4334,  0.3175,  ...,  0.0875, -0.8155, -2.1762],
#          [ 0.0923, -0.2559,  0.9657,  ...,  0.6267, -1.3328, -1.4323],
#          [ 0.1400,  1.5711, -0.4334,  ..., -0.3018, -0.1701,  1.3048],
#          ...,
#          [-2.1696,  2.0499, -0.4450,  ...,  0.5697,  0.9153,  0.1998],
#          [ 1.5531,  1.5662, -0.1666,  ...,  1.5920, -1.0965,  1.6509],
#          [-1.6887,  0.5635, -1.0457,  ...,  0.8283, -1.0899, -0.4530]],
#
#         [[ 0.3886,  0.8608,  0.5717,  ...,  1.5312, -0.4189,  0.8227],
#          [ 1.0661,  0.8652,  1.1571,  ...,  0.0749, -0.8758,  1.2322],
#          [ 0.9072, -0.6837,  1.6863,  ..., -0.2802,  1.1012,  1.5056],
#          ...,
#          [-1.0702,  0.1326, -0.8634,  ...,  0.4076, -0.8895,  1.7638],
#          [-0.6012,  0.4889, -3.1447,  ..., -0.9592, -0.7617,  0.9359],
#          [ 0.0035,  0.1195, -0.8807,  ..., -0.1494, -2.1499,  0.1786]],
#
#         [[-1.2457,  0.4607,  0.0202,  ...,  0.9959, -0.5943, -1.6718],
#          [ 0.6003,  1.6599,  0.9056,  ...,  1.2662,  2.2459, -0.0312],
#          [ 1.5189, -0.3359,  0.7019,  ..., -0.3665, -0.3817,  1.5997],
#          ...,
#          [-2.5704,  0.5256, -0.2156,  ...,  0.3686, -1.1799, -1.2413],
#          [-0.6002,  0.7476, -1.3779,  ..., -0.8950, -1.3544,  0.5400],
#          [ 0.1948,  0.6805, -0.1525,  ..., -1.6961,  0.3527,  0.4948]],
#
#         [[ 1.8538, -0.8410, -0.0183,  ...,  0.3461, -1.3110, -0.4188],
#          [-0.9960, -0.8985,  0.1621,  ...,  0.6471,  0.2333,  1.2505],
#          [ 0.0429, -0.9505, -0.3364,  ..., -1.2680,  1.2939, -0.4236],
#          ...,
#          [ 1.5862, -1.5585, -0.3505,  ..., -0.0505, -0.5124, -1.3284],
#          [-0.9271, -0.5646, -0.6344,  ...,  0.9937, -0.1589,  1.4634],
#          [ 0.1585,  2.6223,  1.1672,  ...,  0.5598,  0.6450, -1.5463]]],
#        grad_fn=<MulBackward0>)
